# %%
Ans-1=
'Guido van Rossum' developed python 
programming language.

Ans2=
python is object oriented programming
and structured programming are fully
supported,and many of their features
support functional programming and aspect-
oriented programming.

Ans3=
Python is case-sensitive language,i.e ,it 
trats uppercase and lowercase characters 
differently.this applies to identifiers too.

Ans4=
The extension of the python file-=( .py,.pyi,
.pyc,.pyd,.pyo,.pyw,.pyz )

Ans5=
The python code are interpreted.

Ans6=
A python program is costructed from code
blocks .A block is apiece of python program
text that is executed as a unit.
the follwing are blocks:a module,a function
body,and a class definition.

Ans7=
We can write a single line comment by 
adding a single # before any statment 
or line of code.

Ans8=
Function is - sys.version .

Ans9=
using a construct called 'lambda'.

Ans10=
pip stands for "preferred installer program".

Ans11=
python built-in functions are given below
print()function.
type()function.
abs()function.
pow()function.
max()function.
sorted()function.
dir()function.
input()function.

Ans12=
Maximum possible length of an identifier in
python is 79 characters.

Ans13=
The benifits are given below-
Data Science
Scientific and mathmatical computing 
web development
finance and trading 
system automation and administration
computer graphics 
Basic game development.etc

Ans14=
Memory management in python involves a
private heap containing all python objects
and data structures.The management of private
heap is ensured internally by the python 
memory manager.

Ans15=
The complete path of python.exe can added by:
1.Right clicking This pc and going to 
properties.
2.Clicking on advanced system setting in 
the menu on the left.
3.Clicking on the envirnomebnt variables 
button  on the bottom right.
4.in the system variable section ,selecting
the path variable and clicking on edit.

Ans16=
Indentation refers to the spaces at the 
beginning of a code line .where in other 
programming languages the identation in
code is for readability only ,the indentation
in python
# Out:
#   Cell In[1], line 1
#     Ans-1=
#     ^
# SyntaxError: cannot assign to expression
